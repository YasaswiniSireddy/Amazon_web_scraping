# %% [markdown]
# # Importing the required libraries

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
def get_title(soup):

    try:
        # Outer Tag Object
        title = soup.find("span",attrs={"id":'productTitle'}).text.strip()

    except AttributeError:
        title= ""

    return title

# Function to extract Product Price
def get_price(soup):

    try:
        price = soup.find("span",attrs={"class":"a-price-whole"}).text

    except AttributeError:
         price = ""
    return price

# Function to extract Product Rating
def get_rating(soup):

    try:
        rating = soup.find("i", attrs={'class':'a-icon-alt'}).string.strip()
    
    except AttributeError:
        rating = ""	

    return rating


# Function to extract SellerName
def get_sellername(soup):
    try:
        sellername = soup.find("div",attrs={"id":"merchant-info" }).text.strip()
        

    except AttributeError:
        sellername = "Out Of Stock"	

    return sellername

# %%
 HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36', 'Accept-Language': 'en-US, en;q=0.5'})

# %%
    # The webpage URL
    URL = "https://www.amazon.in/s?rh=n%3A6612025031&fs=true&ref=lp_6612025031_sar"

# %%
# HTTP Request
webpage = requests.get(URL, headers=HEADERS)

# %%
 # Soup Object containing all data
soup = BeautifulSoup(webpage.content, "html.parser")

# %%
 # Fetch links as List of Tag Objects
links = soup.find_all("a", attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'})

# %%
    # Store the links
links_list = []

# %%
 # Loop for extracting links from Tag Objects
for link in links:
    links_list.append(link.get('href'))

d = {"title":[], "price":[], "rating":[],"SellerName":[]}

# %%
import numpy as np

# %%
 # Loop for extracting product details from each link 
for link in links_list:
    new_webpage = requests.get("https://www.amazon.in" + link, headers=HEADERS)

    new_soup = BeautifulSoup(new_webpage.content, "html.parser")

    # Function calls to display all necessary product information
    d['title'].append(get_title(new_soup))
    d['price'].append(get_price(new_soup))
    d['rating'].append(get_rating(new_soup))
    d['SellerName'].append(get_sellername(new_soup))

# %%
amazon_df = pd.DataFrame.from_dict(d)
amazon_df['title'].replace('', np.nan, inplace=True)
amazon_df = amazon_df.dropna(subset=['title'])
amazon_df.to_csv("amazon_data.csv", header=True, index=False)

# %%
amazon_df
# Out:
#                                                 title   price rating  \
# 0   Ambrane 50000mAh Powerbank, 20W Fast Charging,...  4,499.
# 1   Oboe Silicon Soft Cover Case for Mi Power Bank...    349.
# 2   Ambrane 10000mAh Magnetic Wireless Power Bank ...  1,899.
# 3   MI Power Bank 3i 20000mAh Lithium Polymer 18W ...  1,979.
# 4   Mi 10000mAH Li-Polymer, Micro-USB and Type C I...  1,179.
# 5   MI 10000mAh Lithium Ion, Lithium Polymer Power...  1,699.
# 6   Ambrane 20000mAh Power Bank with 20W Fast Char...  1,599.
# 7   Ambrane 20000mAh Power Bank, 20W Fast Charging...  1,599.
# 8   Duracell 20000 MAH Slimmest Power Bank with 1 ...  3,099.
# 9   Ambrane 10000mAh Slim Power Bank, 20W Fast Cha...    999.
# 10  URBN 20000 mAh Lithium_Polymer 22.5W Super Fas...  1,499.
# 11  Ambrane 20000mAh Power Bank, 20W Fast Charging...  1,599.
# 12  Ambrane 27000mAh Power Bank, 20W Fast Charging...  2,499.
# 13  Qubo MagZap X1 from Hero Group 5000 mAh Magnet...  2,390.
# 14  Ambrane 10000mAh Slim Power Bank, 20W Fast Cha...    999.
# 15  MI 10000mAh 3i Lithium Polymer Power Bank Dual...  1,299.
# 16  Ambrane 10000mAh Slim Power Bank, 20W Fast Cha...    999.
# 17  Ambrane 10000mAh Slim Power Bank, 20W Fast Cha...    999.
# 18  FLiX(Beetel) New Launch PowerXtreme 10,000mAh ...    599.
# 19  Amazon Basics 5000mAh Li-Polymer Wireless Powe...  1,099.
# 20  URBN 20000 mAh Premium Black Edition Nano Powe...  2,499.
# 21  Amazon Basics 20000mAh 22.5W Lithium-Polymer P...  1,579.
# 22  URBN 20000 mAh Lithium_Polymer 22.5W Super Fas...  1,499.
# 23  Amazon Basics 20000mAh 12W Lithium-Polymer Pow...  1,219.
# 24  URBN 10000 mAh Lithium_Polymer 22.5W Super Fas...  1,199.
# 25  URBN 20000 mAh Premium Nano Power Bank | 22.5W...  2,499.
# 26  Ambrane 27000mAh Power Bank, 20W Fast Charging...  2,499.
# 27  Anker 10000 mAh PD Power Bank, PowerCore (Seri...  1,999.
# 28  Redmi 20000mAh Li-Polymer Power Bank, USB Type...  2,049.
# 29  Duracell Power Bank 10000 mAh, Portable Charge...  1,999.
# 30  Ambrane 27000mAh Li-Polymer Powerbank with Typ...  2,399.
# 31  DR VAKU® 10000mAh Power Bank Clear Bolt Portab...  1,399.
# 32  Ambrane 20000mAh Power Bank with 20W Fast Char...  1,599.
#
#                                            SellerName
# 0     Sold by Cocoblu Retail and Fulfilled by Amazon.
# 1   Sold by Dealfreez Estore and Fulfilled by Amazon.
# 2     Sold by Cocoblu Retail and Fulfilled by Amazon.
# 3     Sold by Cocoblu Retail and Fulfilled by Amazon.
# 4     Sold by Cocoblu Retail and Fulfilled by Amazon.
# 5     Sold by Cocoblu Retail and Fulfilled by Amazon.
# 6     Sold by Cocoblu Retail and Fulfilled by Amazon.
# 7     Sold by Cocoblu Retail and Fulfilled by Amazon.
# 8     Sold by Cocoblu Retail and Fulfilled by Amazon.
# 9     Sold by Cocoblu Retail and Fulfilled by Amazon.
# 10    Sold by Cocoblu Retail and Fulfilled by Amazon.
# 11    Sold by Cocoblu Retail and Fulfilled by Amazon.
# 12    Sold by Cocoblu Retail and Fulfilled by Amazon.
# 13  Sold by QUBO by Hero Group and Fulfilled by Am...
# 14    Sold by Cocoblu Retail and Fulfilled by Amazon.
# 15    Sold by Cocoblu Retail and Fulfilled by Amazon.
# 16    Sold by Cocoblu Retail and Fulfilled by Amazon.
# 17    Sold by Cocoblu Retail and Fulfilled by Amazon.
# 18    Sold by Cocoblu Retail and Fulfilled by Amazon.
# 19  Sold by Appario Retail Private Ltd and Fulfill...
# 20    Sold by Cocoblu Retail and Fulfilled by Amazon.
# 21  Sold by Appario Retail Private Ltd and Fulfill...
# 22    Sold by Cocoblu Retail and Fulfilled by Amazon.
# 23  Sold by Appario Retail Private Ltd and Fulfill...
# 24    Sold by Cocoblu Retail and Fulfilled by Amazon.
# 25    Sold by Cocoblu Retail and Fulfilled by Amazon.
# 26    Sold by Cocoblu Retail and Fulfilled by Amazon.
# 27  Sold by Frootle India Pvt Ltd (FIPL) and Fulfi...
# 28    Sold by Cocoblu Retail and Fulfilled by Amazon.
# 29    Sold by Cocoblu Retail and Fulfilled by Amazon.
# 30    Sold by Cocoblu Retail and Fulfilled by Amazon.
# 31        Sold by ellersante and Fulfilled by Amazon.
# 32    Sold by Cocoblu Retail and Fulfilled by Amazon.
